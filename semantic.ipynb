# %%
simple_rag = [
"the jet energy is dissipated outside the cool core",
"actual sensitivity is in fact determined by the number of beams penetrating the region of potential sensitivity",
"photons may be produced according to two possible mechanisms: either they take part directly to the hard subprocess (direct mechanism), or they result from the fragmentation of large transverse momentum partons (fragmentation mechanism)",
"sources and destinations are paired up one-to-one in an arbitrary fashion",
"the algebra of the constraints is closed for any quantum potential when restricted to the quantum Bohmian trajectories and hence there is no inconsistency in the sense of Dirac, neither for quantum geometrodynamics, nor for quantum field theory",
"the results presented here are based on a sample of 100 galaxies selected from the SDSS",
"the idea that our universe contains a vast number of light scalar fields is also based on expectations from landscape models",
"the system is particularly interesting because it is the only gamma-ray binary system where the nature of the compact object is known",
"the idea that local equilibrium patches are embedded in turbulence forms the basis of the present work",
"the distribution of mass ratios for stellar companions to hot Jupiter systems peaks at small values and therefore differs from that of field star binaries which tend to be uniformly distributed across all mass ratios",
"as the numerical model for microswimmers, we employed the squirmer model; in this model, the microswimmers are expressed by rigid particles with a prescribed flow field on their surface",
"the magnetic moment is one of the fundamental properties of the nucleon",
"the algebra of the constraints is closed for any quantum potential when restricted to the quantum Bohmian trajectories and hence there is no inconsistency in the sense of Dirac, neither for quantum geometrodynamics, nor for quantum field theory",
"clusters of galaxies trace the largest gravitationally bound mass concentrations in the universe",
"radiative decays of heavy quarkonia, where a photon replaces one of the three gluons from the strong decay, are useful in studying color-singlet two-gluon systems"
]

advanced_rag = [
"The jet energy is dissipated primarily outside the cool core, with a substantial fraction transported to radii beyond the core region, indicating that AGN feedback redistributes energy well outside the central cool core.",
"The actual sensitivity is determined by the effective system performance, including instrument characteristics, calibration accuracy, observing strategy, and non-ideal effects that reduce sensitivity below nominal values.",
"Photons may be produced either by bremsstrahlung or direct emission from hard partons, or by secondary processes such as fragmentation or scattering-mediated radiation.",
"Sources and destinations are paired according to the network’s connectivity structure, with node pairs linked via edges in a way that balances efficiency, robustness, and throughput.",
"There is insufficient information in the provided sources to conclude the consistency result for the constraint algebra in this context.",
"The galaxy results are based on observations from the Sloan Digital Sky Survey (SDSS), using morphologically classified samples.",
"The idea of many light scalar fields is motivated by string-theory–inspired landscape models that predict numerous vacua with associated scalar fields.",
"The gamma-ray binary is particularly interesting because the nature of its compact object is known, allowing detailed study of emission mechanisms and system dynamics.",
"The key assumption is that local equilibrium patches are embedded within turbulence, forming locally relaxed states inside a globally turbulent flow.",
"The mass-ratio distribution of stellar companions to hot Jupiter systems is biased toward lower mass ratios compared to field star binaries.",
"Microswimmers are modeled using a numerical hydrodynamic scheme in which swimmers are represented as self-propelled particles with prescribed surface flows or particle-based representations resolving fluid–solid interactions.",
"The magnetic moment is fundamental because it is an intrinsic property of the nucleon tied to its internal structure and provides a stringent test of quantum chromodynamics.",
"The algebra of constraints remains closed only if the quantum potential does not violate the Dirac–Teitelboim algebra, ensuring consistent Hamiltonian evolution.",
"Clusters of galaxies trace the large-scale cosmic structure and the distribution of the most massive, gravitationally bound matter concentrations.",
"Radiative decays of heavy quarkonia are useful because they provide a clean probe of color-singlet two-gluon systems and constrain quantum chromodynamic dynamics."
]

ai_with_internet = [
"The jet energy is deposited outside the cool core, at roughly a few ×100 kpc from the cluster centre.",
"The actual sensitivity is set by the effective system performance in practice (e.g., digitization losses, telescope gain/declination effects, and other non-idealities that reduce sensitivity below the nominal value).",
"Either produced directly in the hard subprocess, or produced via parton fragmentation.",
"They are paired one-to-one in an arbitrary fashion.",
"It is consistent: the constraint algebra closes (no inconsistency) when restricted to quantum Bohmian trajectories, for any quantum potential.",
"Based on a first sample of about 55,000 galaxies from the VIPERS survey.",
"String-theory–motivated frameworks (e.g., higher-dimensional/brane-world compactifications) that generically yield many light moduli/scalar fields.",
"Because it is (in that discussion) the only gamma-ray binary where the nature of the compact object is known.",
"That turbulence is locally in equilibrium: production balances dissipation (within each local patch).",
"It peaks at small mass ratios (low-q companions), unlike field-star binaries which are roughly flat/uniform across mass ratio.",
"The squirmer model; swimmers are rigid particles with a prescribed surface flow/slip (surface velocity field) that generates self-propulsion.",
"Because it is an intrinsic dipole property that reveals nucleon internal structure (e.g., the neutron’s moment despite zero net charge) and governs key electromagnetic interactions/probes.",
"When restricted to quantum Bohmian trajectories (i.e., on that restricted sector), the constraint algebra remains closed.",
"They trace the large-scale distribution of matter (the cosmic web) in the Universe.",
"Because they provide access to a color-singlet two-gluon system (photon replaces one gluon), letting one study two-gluon hadronization and glueball/meson formation channels."
]

ai_without_internet = [
"Insufficient information to answer (depends on the specific system or paper; the source text is required).",
"Determined by the instrument and observing strategy, including collecting area, throughput, exposure time, background, beam or PSF, bandwidth, system temperature, efficiency, and detection method.",
"Either direct emission from primary particles or secondary emission after interactions such as inverse-Compton scattering or hadronic processes.",
"Paired one-to-one in an arbitrary fashion.",
"Insufficient information to answer (paper-specific conclusion; the quoted result is required).",
"Insufficient information to answer (depends on which survey and sample size; the source text is required).",
"Typically motivated by string theory, where compactifications generically yield many light scalar fields.",
"Insufficient information to answer (depends on which gamma-ray binary and which property is highlighted).",
"Insufficient information to answer (likely assumes local statistical stationarity, but the source text is required).",
"Insufficient information to answer (this is an empirical comparison requiring the source data or figure).",
"Insufficient information to answer (the numerical model and representation are paper-specific).",
"Because it probes the nucleon’s intrinsic spin and charge-current structure, reflecting internal quark–gluon dynamics.",
"Insufficient information to answer (the restriction ensuring closure is formulation-specific).",
"They trace the underlying large-scale matter distribution, i.e., the cosmic web.",
"Because the radiative photon tags a gluon-rich intermediate state, enabling cleaner study of two-gluon dynamics."
]

ground_truth = [
"the jet energy is dissipated outside the cool core",
"actual sensitivity is in fact determined by the number of beams penetrating the region of potential sensitivity",
"photons may be produced according to two possible mechanisms: either they take part directly to the hard subprocess, or they result from the fragmentation of large transverse momentum partons",
"sources and destinations are paired up one-to-one in an arbitrary fashion",
"the algebra of the constraints is closed for any quantum potential when restricted to the quantum Bohmian trajectories and hence there is no inconsistency in the sense of Dirac, neither for quantum geometrodynamics, nor for quantum field theory",
"the results presented here are based on a sample of 100 galaxies selected from the SDSS",
"the idea that our universe contains a vast number of light scalar fields is also based on expectations from landscape models",
"the system is particularly interesting because it is the only gamma-ray binary system where the nature of the compact object is known",
"the idea that local equilibrium patches are embedded in turbulence forms the basis of the present work",
"the distribution of mass ratios for stellar companions to hot Jupiter systems peaks at small values and therefore differs from that of field star binaries which tend to be uniformly distributed across all mass ratios",
"as the numerical model for microswimmers, we employed the squirmer model; in this model, the microswimmers are expressed by rigid particles with a prescribed flow field on their surface",
"the magnetic moment is one of the fundamental properties of the nucleon",
"the algebra of the constraints is closed for any quantum potential when restricted to the quantum Bohmian trajectories and hence there is no inconsistency in the sense of Dirac, neither for quantum geometrodynamics, nor for quantum field theory",
"clusters of galaxies trace the largest gravitationally bound mass concentrations in the universe",
"radiative decays of heavy quarkonia, where a photon replaces one of the three gluons from the strong decay, are useful in studying color-singlet two-gluon systems"
]
